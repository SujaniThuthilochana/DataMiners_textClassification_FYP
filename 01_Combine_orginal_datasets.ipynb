# %%
import pandas as pd

# List the names of the CSV files
csv_files = ['April12_2020.csv','Jan12_2021.csv','April28_2021.csv','Jan24_2022.csv']

# Create an empty list to store the DataFrames
df_list = []

# Iterate over the CSV files
for file in csv_files:
    # Read the CSV file into a DataFrame
    df = pd.read_csv(file)
    # Add the DataFrame to the list
    df_list.append(df)

# Concatenate the DataFrames into a single DataFrame
combined_df = pd.concat(df_list)

# Write the combined DataFrame to a CSV file
combined_df.to_csv('combined_final_orginal_dataset.csv', index=False)
# Out:
# C:\Users\mksuj\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3106: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
import pandas as pd

# Read the Excel file into a DataFrame
df = pd.read_csv('combined_final_orginal_dataset.csv')

# Get the number of rows in the DataFrame
num_rows = df.shape[0]

# Print the number of rows
print(num_rows)
# Out:
# 264919

# %%
df.head()
# Out:
#   coordinates                      created_at hashtags media urls  \
# 0         NaN  Sat Apr 04 12:04:28 +0000 2020      NaN   NaN  NaN
# 1         NaN  Sat Apr 04 12:04:28 +0000 2020  COVID19   NaN  NaN
# 2         NaN  Sat Apr 04 12:04:28 +0000 2020  COVID19   NaN  NaN
# 3         NaN  Sat Apr 04 12:04:28 +0000 2020      NaN   NaN  NaN
# 4         NaN  Sat Apr 04 12:04:28 +0000 2020      NaN   NaN  NaN
#
#    favorite_count                   id in_reply_to_screen_name  \
# 0               0  1246408292240261120             maeplebacon
# 1               0  1246408292571594754                     NaN
# 2               0  1246408292634689536                     NaN
# 3               0  1246408292424957953                     NaN
# 4               0  1246408292751958016               PIB_India
#
#    in_reply_to_status_id  in_reply_to_user_id  ... user_followers_count  \
# 0           1.246408e+18         8.881185e+17  ...                   10
# ...
